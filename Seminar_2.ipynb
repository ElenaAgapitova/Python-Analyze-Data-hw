# %%
import pandas as pd
import numpy as np

# %%
a = pd.Series([4,7,6,3,9],
              index=['one', 'two','three', 'four', 'five'])
a
# Out:
# one      4
# two      7
# three    6
# four     3
# five     9
# dtype: int64

# %%
df = pd.read_csv('./Churn_Modelling.csv')
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
df['Age'].isnull().sum()
# Out:
# 0

# %%
df['Age'].median()
# Out:
# 37.0

# %%
df['Age'].mean()
# Out:
# 38.9218

# %% [markdown]
# ## Задача 1

# %% [markdown]
# Скачать данные по ссылке https://www.kaggle.com/datasets/ionaskel/laptop-prices
# Считать данные с помощью pandas
# Вывести на экран первые 5 строк
# Посмотреть на описание признаков и на их содержание

# %%
data = pd.read_csv('./laptop_price.csv', encoding='1251')
data
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# 1              Ultrabook    13.3                                    1440x900
# 2               Notebook    15.6                           Full HD 1920x1080
# 3              Ultrabook    15.4          IPS Panel Retina Display 2880x1800
# 4              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...                  ...     ...                                         ...
# 1298  2 in 1 Convertible    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  2 in 1 Convertible    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300            Notebook    14.0                                    1366x768
# 1301            Notebook    15.6                                    1366x768
# 1302            Notebook    15.6                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94
# 2            Intel HD Graphics 620       No OS  1.86kg       575.00
# 3               AMD Radeon Pro 455       macOS  1.83kg      2537.45
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg      1803.60
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg       638.00
# 1299         Intel HD Graphics 520  Windows 10   1.3kg      1499.00
# 1300             Intel HD Graphics  Windows 10   1.5kg       229.00
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg       764.00
# 1302             Intel HD Graphics  Windows 10   2.2kg       369.00
#
# [1303 rows x 13 columns]

# %%
data.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros
# 0      1339.69
# 1       898.94
# 2       575.00
# 3      2537.45
# 4      1803.60

# %%
data.describe()
# Out:
#          laptop_ID       Inches  Price_euros
# count  1303.000000  1303.000000  1303.000000
# mean    660.155794    15.017191  1123.686992
# std     381.172104     1.426304   699.009043
# min       1.000000    10.100000   174.000000
# 25%     331.500000    14.000000   599.000000
# 50%     659.000000    15.600000   977.000000
# 75%     990.500000    15.600000  1487.880000
# max    1320.000000    18.400000  6099.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   object
#  8   Memory            1303 non-null   object
#  9   Gpu               1303 non-null   object
#  10  OpSys             1303 non-null   object
#  11  Weight            1303 non-null   object
#  12  Price_euros       1303 non-null   float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 132.5+ KB

# %% [markdown]
# ## Задача 2
# Проведите первичный анализ данных
# Изучите типы данных
# Найдите количество пропущенных ячеек в данных
# Посчитайте основные статистики по всем признакам и поизучайте их

# %%
data[['Inches', 'Price_euros']].describe()
# Out:
#             Inches  Price_euros
# count  1303.000000  1303.000000
# mean     15.017191  1123.686992
# std       1.426304   699.009043
# min      10.100000   174.000000
# 25%      14.000000   599.000000
# 50%      15.600000   977.000000
# 75%      15.600000  1487.880000
# max      18.400000  6099.000000

# %%
data.isnull().sum()
# Out:
# laptop_ID           0
# Company             0
# Product             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price_euros         0
# dtype: int64

# %%
data.isnull()
# Out:
#       laptop_ID  Company  Product  TypeName  Inches  ScreenResolution    Cpu  \
# 0         False    False    False     False   False             False  False
# 1         False    False    False     False   False             False  False
# 2         False    False    False     False   False             False  False
# 3         False    False    False     False   False             False  False
# 4         False    False    False     False   False             False  False
# ...         ...      ...      ...       ...     ...               ...    ...
# 1298      False    False    False     False   False             False  False
# 1299      False    False    False     False   False             False  False
# 1300      False    False    False     False   False             False  False
# 1301      False    False    False     False   False             False  False
# 1302      False    False    False     False   False             False  False
#
#         Ram  Memory    Gpu  OpSys  Weight  Price_euros
# 0     False   False  False  False   False        False
# 1     False   False  False  False   False        False
# 2     False   False  False  False   False        False
# 3     False   False  False  False   False        False
# 4     False   False  False  False   False        False
# ...     ...     ...    ...    ...     ...          ...
# 1298  False   False  False  False   False        False
# 1299  False   False  False  False   False        False
# 1300  False   False  False  False   False        False
# 1301  False   False  False  False   False        False
# 1302  False   False  False  False   False        False
#
# [1303 rows x 13 columns]

# %%
data.describe(include=['object'])
# Out:
#        Company Product  TypeName   ScreenResolution  \
# count     1303    1303      1303               1303
# unique      19     618         6                 40
# top       Dell  XPS 13  Notebook  Full HD 1920x1080
# freq       297      30       727                507
#
#                                Cpu   Ram     Memory                    Gpu  \
# count                         1303  1303       1303                   1303
# unique                         118     9         39                    110
# top     Intel Core i5 7200U 2.5GHz   8GB  256GB SSD  Intel HD Graphics 620
# freq                           190   619        412                    281
#
#              OpSys Weight
# count         1303   1303
# unique           9    179
# top     Windows 10  2.2kg
# freq          1072    121

# %% [markdown]
# ## Задача 3
# Ответьте на несколько вопросов
# 3.1 Ноутбуков от какой компании больше всего в наборе данных?
# 3.2 Какая минимальная и максимальная стоимость у ноутбуков в данных?
# 3.3 Какой самый дорогой ноутбук в данных?
# Выведите все характеристики только по этому ноутбуку
# Если таких ноутбуков несколько, то выводите их всех

# %%
data.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros
# 0      1339.69
# 1       898.94
# 2       575.00
# 3      2537.45
# 4      1803.60

# %%
data['Company'].value_counts()
# Out:
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: Company, dtype: int64

# %%
data['Price_euros'].min()
# Out:
# 174.0

# %%
data['Price_euros'].max()
# Out:
# 6099.0

# %%
data['Company'].value_counts().idxmax()
# Out:
# 'Dell'

# %%
data['Company'].value_counts().loc[lambda x: x==data['Company'].value_counts().max()]
# Out:
# Dell      297
# Lenovo    297
# Name: Company, dtype: int64

# %%
data1 = data['Company'].value_counts().loc[lambda x: x==data['Company'].value_counts().max()]

# %%
data1
# Out:
# Dell      297
# Lenovo    297
# Name: Company, dtype: int64

# %%
data1['Dell']
# Out:
# 297

# %%
data[data['Price_euros'] ==  data['Price_euros'].max()]
# Out:
#      laptop_ID Company    Product TypeName  Inches  \
# 196        200   Razer  Blade Pro   Gaming    17.3
#
#                         ScreenResolution                          Cpu   Ram  \
# 196  4K Ultra HD / Touchscreen 3840x2160  Intel Core i7 7820HK 2.9GHz  32GB
#
#       Memory                      Gpu       OpSys  Weight  Price_euros
# 196  1TB SSD  Nvidia GeForce GTX 1080  Windows 10  3.49kg       6099.0

# %%
data['Price_euros'].value_counts().max()
# Out:
# 14

# %%
data['Price_euros'].value_counts().sort_index()
# Out:
# 174.0     1
# 191.9     1
# 196.0     1
# 199.0     2
# 202.9     1
#          ..
# 3975.0    1
# 4389.0    1
# 4899.0    1
# 5499.0    1
# 6099.0    1
# Name: Price_euros, Length: 791, dtype: int64

# %%
data[data['Price_euros'] ==  1499.0]
# Out:
#       laptop_ID  Company            Product            TypeName  Inches  \
# 41           42     Dell      Inspiron 7577              Gaming    15.6
# 179         183       HP       Spectre x360  2 in 1 Convertible    13.3
# 214         219   Huawei         MateBook X           Ultrabook    13.0
# 232         237   Lenovo  Legion Y720-15IKB              Gaming    15.6
# 266         271     Asus       ZenBook Flip  2 in 1 Convertible    13.3
# 684         692   Lenovo           Yoga 730  2 in 1 Convertible    13.3
# 722         730   Lenovo     ThinkPad T470s           Ultrabook    14.0
# 802         811     Dell             XPS 13           Ultrabook    13.3
# 812         821  Samsung         Notebook 9           Ultrabook    13.3
# 1160       1178   Lenovo      ThinkPad T460           Ultrabook    14.0
# 1239       1257   Lenovo        ThinkPad 13            Notebook    13.3
# 1271       1289   Lenovo     Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1285       1303   Lenovo     Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1299       1317   Lenovo     Yoga 900-13ISK  2 in 1 Convertible    13.3
#
#                                    ScreenResolution  \
# 41                      IPS Panel Full HD 1920x1080
# 179   IPS Panel 4K Ultra HD / Touchscreen 3840x2160
# 214                     IPS Panel Full HD 2160x1440
# 232                     IPS Panel Full HD 1920x1080
# 266                 Full HD / Touchscreen 1920x1080
# 684       IPS Panel Full HD / Touchscreen 1920x1080
# 722                     IPS Panel Full HD 1920x1080
# 802                               Full HD 1920x1080
# 812                               Full HD 1920x1080
# 1160                              Full HD 1920x1080
# 1239                    IPS Panel Full HD 1920x1080
# 1271     IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1285     IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1299     IPS Panel Quad HD+ / Touchscreen 3200x1800
#
#                               Cpu   Ram                  Memory  \
# 41    Intel Core i7 7700HQ 2.8GHz  16GB    256GB SSD +  1TB HDD
# 179    Intel Core i5 8250U 1.6GHz   8GB               256GB SSD
# 214    Intel Core i7 7500U 2.7GHz   8GB               512GB SSD
# 232   Intel Core i7 7700HQ 2.8GHz  16GB    256GB SSD +  1TB HDD
# 266    Intel Core i7 8550U 1.8GHz   8GB  512GB SSD +  512GB SSD
# 684    Intel Core i7 8550U 1.8GHz   8GB               512GB SSD
# 722    Intel Core i5 7200U 2.5GHz   8GB               256GB SSD
# 802    Intel Core i5 7200U 2.5GHz   8GB               256GB SSD
# 812    Intel Core i5 7200U 2.5GHz   8GB               256GB SSD
# 1160   Intel Core i7 6600U 2.6GHz   8GB               256GB SSD
# 1239   Intel Core i7 7500U 2.7GHz  16GB               512GB SSD
# 1271   Intel Core i7 6500U 2.5GHz  16GB               512GB SSD
# 1285   Intel Core i7 6500U 2.5GHz  16GB               512GB SSD
# 1299   Intel Core i7 6500U 2.5GHz  16GB               512GB SSD
#
#                           Gpu       OpSys  Weight  Price_euros
# 41    Nvidia GeForce GTX 1060  Windows 10  2.65kg       1499.0
# 179    Intel UHD Graphics 620  Windows 10  1.29kg       1499.0
# 214     Intel HD Graphics 620  Windows 10  1.05kg       1499.0
# 232   Nvidia GeForce GTX 1060  Windows 10   3.2kg       1499.0
# 266    Intel UHD Graphics 620  Windows 10   1.1kg       1499.0
# 684    Intel UHD Graphics 620  Windows 10  1.19kg       1499.0
# 722     Intel HD Graphics 620  Windows 10  1.32kg       1499.0
# 802     Intel HD Graphics 620  Windows 10  1.29kg       1499.0
# 812     Intel HD Graphics 620  Windows 10  0.81kg       1499.0
# 1160    Intel HD Graphics 520   Windows 7   1.7kg       1499.0
# 1239    Intel HD Graphics 620  Windows 10   1.4kg       1499.0
# 1271    Intel HD Graphics 520  Windows 10   1.3kg       1499.0
# 1285    Intel HD Graphics 520  Windows 10   1.3kg       1499.0
# 1299    Intel HD Graphics 520  Windows 10   1.3kg       1499.0

# %% [markdown]
# ## Задача 4
# Ответьте на несколько вопросов
# 4.1 Найдите ноутбуки с самой маленькой диагональю в данных?
# Выведите только следующие характеристики:
# Компания
# Типа ноутбука
# Диагональ
# Стоимость
# Если таких ноутбуков несколько, то выводите их всех
# 4.2 Сколько стоит самый дорогой ноутбук у компании HP?
# 4.3 Как много ноутбуков Ultrabook с 8GB RAM?
# Найдите сколько таких ультрабуков с 8GB ОЗУ в процентном соотношении относительно всех ультрабуков

# %%
data[data['Inches'] == data['Inches'].min()][['Company', 'TypeName', 'Inches', 'Price_euros']]
# Out:
#      Company            TypeName  Inches  Price_euros
# 50    Lenovo  2 in 1 Convertible    10.1       319.00
# 1082  Lenovo  2 in 1 Convertible    10.1       646.27
# 1114  Lenovo  2 in 1 Convertible    10.1       549.00
# 1126  Lenovo  2 in 1 Convertible    10.1       479.00

# %%
data2 = data[data['Company'] == 'HP']
data2[data2['Price_euros'] == data2['Price_euros'].max()]
# Out:
#      laptop_ID Company   Product     TypeName  Inches  \
# 749        758      HP  Zbook 17  Workstation    17.3
#
#                 ScreenResolution                            Cpu   Ram  \
# 749  IPS Panel Full HD 1920x1080  Intel Xeon E3-1535M v5 2.9GHz  16GB
#
#         Memory                   Gpu      OpSys Weight  Price_euros
# 749  256GB SSD  Nvidia Quadro M2000M  Windows 7    3kg       4389.0

# %%
data[data['Company'] == 'HP']
# Out:
#       laptop_ID Company                                  Product   TypeName  \
# 2             3      HP                                   250 G6   Notebook
# 10           11      HP                                   250 G6   Notebook
# 11           12      HP                                   250 G6   Notebook
# 22           23      HP                                   255 G6   Notebook
# 24           25      HP  15-BS101nv (i7-8550U/8GB/256GB/FHD/W10)  Ultrabook
# ...         ...     ...                                      ...        ...
# 1282       1300      HP                         Stream 11-Y000na    Netbook
# 1287       1305      HP      15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook
# 1294       1312      HP                      Pavilion 15-AW003nv   Notebook
# 1296       1314      HP                         Stream 11-Y000na    Netbook
# 1301       1319      HP      15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook
#
#       Inches   ScreenResolution                                   Cpu  Ram  \
# 2       15.6  Full HD 1920x1080            Intel Core i5 7200U 2.5GHz  8GB
# 10      15.6           1366x768            Intel Core i5 7200U 2.5GHz  4GB
# 11      15.6  Full HD 1920x1080              Intel Core i3 6006U 2GHz  4GB
# 22      15.6           1366x768          AMD E-Series E2-9000e 1.5GHz  4GB
# 24      15.6  Full HD 1920x1080            Intel Core i7 8550U 1.8GHz  8GB
# ...      ...                ...                                   ...  ...
# 1282    11.6           1366x768  Intel Celeron Dual Core N3060 1.6GHz  2GB
# 1287    15.6           1366x768            Intel Core i7 6500U 2.5GHz  6GB
# 1294    15.6  Full HD 1920x1080             AMD A9-Series 9410 2.9GHz  6GB
# 1296    11.6           1366x768  Intel Celeron Dual Core N3060 1.6GHz  2GB
# 1301    15.6           1366x768            Intel Core i7 6500U 2.5GHz  6GB
#
#                   Memory                    Gpu       OpSys  Weight  \
# 2              256GB SSD  Intel HD Graphics 620       No OS  1.86kg
# 10             500GB HDD  Intel HD Graphics 620       No OS  1.86kg
# 11             500GB HDD  Intel HD Graphics 520       No OS  1.86kg
# 22             500GB HDD          AMD Radeon R2       No OS  1.86kg
# 24             256GB SSD  Intel HD Graphics 620  Windows 10  1.91kg
# ...                  ...                    ...         ...     ...
# 1282  32GB Flash Storage  Intel HD Graphics 400  Windows 10  1.17kg
# 1287             1TB HDD     AMD Radeon R5 M330  Windows 10  2.19kg
# 1294        1.0TB Hybrid     AMD Radeon R7 M440  Windows 10  2.04kg
# 1296  32GB Flash Storage  Intel HD Graphics 400  Windows 10  1.17kg
# 1301             1TB HDD     AMD Radeon R5 M330  Windows 10  2.19kg
#
#       Price_euros
# 2          575.00
# 10         393.90
# 11         344.99
# 22         258.00
# 24         659.00
# ...           ...
# 1282       209.00
# 1287       764.00
# 1294       549.99
# 1296       209.00
# 1301       764.00
#
# [274 rows x 13 columns]

# %%
data[data["Price_euros"] == data[data['Company'] == 'HP']['Price_euros'].max()]
# Out:
#      laptop_ID Company   Product     TypeName  Inches  \
# 749        758      HP  Zbook 17  Workstation    17.3
#
#                 ScreenResolution                            Cpu   Ram  \
# 749  IPS Panel Full HD 1920x1080  Intel Xeon E3-1535M v5 2.9GHz  16GB
#
#         Memory                   Gpu      OpSys Weight  Price_euros
# 749  256GB SSD  Nvidia Quadro M2000M  Windows 7    3kg       4389.0

# %%
data[(data['TypeName'] == 'Ultrabook') & (data['Ram'] == '8GB')]
# Out:
#       laptop_ID Company               Product   TypeName  Inches  \
# 0             1   Apple           MacBook Pro  Ultrabook    13.3
# 1             2   Apple           Macbook Air  Ultrabook    13.3
# 4             5   Apple           MacBook Pro  Ultrabook    13.3
# 7             8   Apple           Macbook Air  Ultrabook    13.3
# 9            10    Acer               Swift 3  Ultrabook    14.0
# ...         ...     ...                   ...        ...     ...
# 1236       1254      HP         EliteBook 840  Ultrabook    14.0
# 1241       1259    Asus  ZenBook UX310UA-WB71  Ultrabook    13.3
# 1261       1279    Asus  ZenBook UX305CA-UBM1  Ultrabook    13.3
# 1275       1293    Asus  ZenBook UX305CA-UBM1  Ultrabook    13.3
# 1289       1307    Asus  ZenBook UX305CA-UBM1  Ultrabook    13.3
#
#                         ScreenResolution                         Cpu  Ram  \
# 0     IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz  8GB
# 1                               1440x900        Intel Core i5 1.8GHz  8GB
# 4     IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz  8GB
# 7                               1440x900        Intel Core i5 1.8GHz  8GB
# 9            IPS Panel Full HD 1920x1080  Intel Core i5 8250U 1.6GHz  8GB
# ...                                  ...                         ...  ...
# 1236                           2560x1440  Intel Core i7 6500U 2.5GHz  8GB
# 1241                   Full HD 1920x1080  Intel Core i7 6500U 2.5GHz  8GB
# 1261         IPS Panel Full HD 1920x1080    Intel Core M 6Y30 0.9GHz  8GB
# 1275         IPS Panel Full HD 1920x1080    Intel Core M 6Y30 0.9GHz  8GB
# 1289         IPS Panel Full HD 1920x1080    Intel Core M 6Y30 0.9GHz  8GB
#
#                    Memory                           Gpu       OpSys  Weight  \
# 0               128GB SSD  Intel Iris Plus Graphics 640       macOS  1.37kg
# 1     128GB Flash Storage        Intel HD Graphics 6000       macOS  1.34kg
# 4               256GB SSD  Intel Iris Plus Graphics 650       macOS  1.37kg
# 7     256GB Flash Storage        Intel HD Graphics 6000       macOS  1.34kg
# 9               256GB SSD        Intel UHD Graphics 620  Windows 10   1.6kg
# ...                   ...                           ...         ...     ...
# 1236            256GB SSD         Intel HD Graphics 520   Windows 7  1.54kg
# 1241            256GB SSD         Intel HD Graphics 520  Windows 10  1.45kg
# 1261            512GB SSD         Intel HD Graphics 515  Windows 10   1.2kg
# 1275            512GB SSD         Intel HD Graphics 515  Windows 10   1.2kg
# 1289            512GB SSD         Intel HD Graphics 515  Windows 10   1.2kg
#
#       Price_euros
# 0         1339.69
# 1          898.94
# 4         1803.60
# 7         1158.70
# 9          770.00
# ...           ...
# 1236      2198.19
# 1241      1280.00
# 1261       729.00
# 1275       729.00
# 1289       729.00
#
# [140 rows x 13 columns]

# %%
a = data[(data['TypeName'] == 'Ultrabook') & (data['Ram'] == '8GB')].shape[0]

# %%
b = data[data['TypeName'] == 'Ultrabook'].shape[0]

# %%
result = round(a/b * 100)
result
# Out:
# 71

# %%
data[data['TypeName'] == 'Ultrabook']['Ram'].value_counts(normalize=True).loc['8GB'] * 100
# Out:
# 71.42857142857143

# %% [markdown]
# ## Задача 5
# 5.1 Выберите ноутбук клиенту
# Клиент хочет подобрать ноутбук с 8GB или 16GB ОЗУ на Windows 10 в стоимости до 500 евро, сколько у него вариантов?
# 5.2 Выберите ноутбук клиенту
# Клиент хочет подобрать ноутбук от MSI, с видеокартой Nvidia GeForce GTX 1050 Ti и главное не с диагональю 15.6. В какой ценовой категории вышли подобные ноутбуки?
# 5.3 Что дешевле?
# В среднем дешевле ноутбуки с CPU Intel Core i7 7700HQ 2.8GHz или с Intel Core i7 7600U 2.8GHz?

# %%
data[((data['Ram'] == '8GB') | (data['Ram'] == '16GB')) & (data['OpSys']=='Windows 10') & (data['Price_euros'] <= 500)].shape[0]
# Out:
# 13

# %%
data[(data['Ram'].isin(('8GB', '16GB'))) & (data['OpSys']=='Windows 10') & (data['Price_euros'] <= 500)].shape[0]
# Out:
# 13

# %%
data[(data['Company'] == 'MSI') & (data['Gpu']=='Nvidia GeForce GTX 1050 Ti') & (~(data['Inches'] == 15.6))]['Price_euros'].describe()
# Out:
# count       5.000000
# mean     1397.656000
# std       153.167946
# min      1199.000000
# 25%      1348.480000
# 50%      1349.000000
# 75%      1492.800000
# max      1599.000000
# Name: Price_euros, dtype: float64

# %%
a = data[data['Cpu'] == 'Intel Core i7 7700HQ 2.8GHz']['Price_euros'].mean()

# %%
b = data[data['Cpu'] == 'Intel Core i7 7600U 2.8GHz']['Price_euros'].mean()

# %%
b > a
# Out:
# True

# %% [markdown]
# ## Задача 6
# Найдите самый легкий ноутбук
# Но обратите внимание на тип и представление данных в признаке Weight, если что, замените в строке 'kg' на пустую строку через метод .str.replace()

# %%
data
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# 1              Ultrabook    13.3                                    1440x900
# 2               Notebook    15.6                           Full HD 1920x1080
# 3              Ultrabook    15.4          IPS Panel Retina Display 2880x1800
# 4              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...                  ...     ...                                         ...
# 1298  2 in 1 Convertible    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  2 in 1 Convertible    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300            Notebook    14.0                                    1366x768
# 1301            Notebook    15.6                                    1366x768
# 1302            Notebook    15.6                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94
# 2            Intel HD Graphics 620       No OS  1.86kg       575.00
# 3               AMD Radeon Pro 455       macOS  1.83kg      2537.45
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg      1803.60
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg       638.00
# 1299         Intel HD Graphics 520  Windows 10   1.3kg      1499.00
# 1300             Intel HD Graphics  Windows 10   1.5kg       229.00
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg       764.00
# 1302             Intel HD Graphics  Windows 10   2.2kg       369.00
#
# [1303 rows x 13 columns]

# %%
data['Weight'] = data['Weight'].str.replace('kg', '').astype(float)

# %%
data['Weight']
# Out:
# 0       1.37
# 1       1.34
# 2       1.86
# 3       1.83
# 4       1.37
#         ...
# 1298    1.80
# 1299    1.30
# 1300    1.50
# 1301    2.19
# 1302    2.20
# Name: Weight, Length: 1303, dtype: float64

# %%
data[data['Weight'] == data['Weight'].min()]['Product']
# Out:
# 50      Yoga Book
# 1082    Yoga Book
# 1114    Yoga Book
# 1126    Yoga Book
# Name: Product, dtype: object
